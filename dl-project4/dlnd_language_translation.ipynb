# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # DONE: Implement Function
    
    source_sentences_ids = [[source_vocab_to_int[word] for word in sentence.split()] for sentence in source_text.split("\n")]
    target_sentences_ids = [[target_vocab_to_int[word] for word in sentence.split()] + [target_vocab_to_int['<EOS>']] for sentence in target_text.split("\n")]
    
    return source_sentences_ids, target_sentences_ids

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.2.1
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # DONE: Implement Function
    # NOTE: I had to change test_model_inputs to avoid getting this: https://github.com/tensorflow/tensorflow/issues/11315
    
    inputs = tf.placeholder(tf.int32, [None,None], name="input")
    targets = tf.placeholder(tf.int32, [None,None])
    learning_rate = tf.placeholder(tf.float32)
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    target_sequence_length = tf.placeholder(tf.int32, [None], name="target_sequence_length")
    max_target_sequence_length = tf.reduce_max(target_sequence_length, name="max_target_len")
    source_sequence_length = tf.placeholder(tf.int32, [None], name="source_sequence_length")
    return inputs, targets, learning_rate, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # DONE: Implement Function
    ending = tf.strided_slice(target_data, [0,0], [batch_size, -1], strides=[1,1])
    return tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # DONE: Implement Function
    
    embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, vocab_size=source_vocab_size, embed_dim=encoding_embedding_size)
    
    def make_cell(rnn_size):
        cell = tf.contrib.rnn.LSTMCell(rnn_size, initializer=tf.random_uniform_initializer(-0.1, 0.1))
        return tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=keep_prob)    
    enc_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _i in range(num_layers)])
    enc_output, enc_state = tf.nn.dynamic_rnn(enc_cell, embed_input, sequence_length=source_sequence_length, dtype=tf.float32)
    
    return enc_output, enc_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # DONE: Implement Function
    
    # ref: https://github.com/udacity/deep-learning/blob/master/seq2seq/sequence_to_sequence_implementation.ipynb
    
    train_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input,
                                                    sequence_length=target_sequence_length,
                                                    time_major=False)
    
    train_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                    train_helper,
                                                    encoder_state,
                                                    output_layer=output_layer)
    
    train_logits = tf.contrib.seq2seq.dynamic_decode(train_decoder,
                                             impute_finished=True,
                                             maximum_iterations=max_summary_length)[0]
    
    return train_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # DONE: Implement Function
    
    # ref: https://github.com/udacity/deep-learning/blob/master/seq2seq/sequence_to_sequence_implementation.ipynb
    
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')

    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                                start_tokens,
                                                                end_of_sequence_id)

    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                        inference_helper,
                                                        encoder_state,
                                                        output_layer)
    
    inference_decoder_output = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                            impute_finished=True,
                                                            maximum_iterations=max_target_sequence_length)[0]
    
    return inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size, num_layers,
                   target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    
    # DONE: Implement Function
    
    # ref: https://github.com/udacity/deep-learning/blob/master/seq2seq/sequence_to_sequence_implementation.ipynb
    
    # create target sequence embedding
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    # construct decoder cells
    def make_cell(rnn_size):
        cell = tf.contrib.rnn.LSTMCell(rnn_size, initializer=tf.random_uniform_initializer(-0.1, 0.1))
        return tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=keep_prob)    
    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _i in range(num_layers)])
    
    # construct output layer
    output_layer = Dense(target_vocab_size,
                        kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))
    
    # get training and inference outputs
    with tf.variable_scope("decode") as scope:
        training_logits = decoding_layer_train(encoder_state,
                                               dec_cell,
                                               dec_embed_input,
                                               target_sequence_length,
                                               max_target_sequence_length,
                                               output_layer,
                                               keep_prob)

        # https://www.tensorflow.org/programmers_guide/variable_scope
        scope.reuse_variables()
        
        inference_logits = decoding_layer_infer(encoder_state,
                                                dec_cell,
                                                dec_embeddings,
                                                target_vocab_to_int["<GO>"],
                                                target_vocab_to_int["<EOS>"],
                                                max_target_sequence_length,
                                                target_vocab_size,
                                                output_layer,
                                                batch_size,
                                                keep_prob)
    return training_logits, inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # DONE: Implement Function
    
    enc_output, enc_state = encoding_layer(input_data,
                                           rnn_size,
                                           num_layers,
                                           keep_prob,
                                           source_sequence_length,
                                           source_vocab_size,
                                           enc_embedding_size)
    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    return decoding_layer(dec_input,
                          enc_state,
                          target_sequence_length,
                          max_target_sentence_length,
                          rnn_size,
                          num_layers,
                          target_vocab_to_int,
                          target_vocab_size,
                          batch_size,
                          keep_prob,
                          dec_embedding_size)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 5
# Batch Size
batch_size = 256
# RNN Size
rnn_size = 512
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 100
decoding_embedding_size = 100
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.5
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   10/538 - Train Accuracy: 0.3418, Validation Accuracy: 0.4217, Loss: 3.4451
# Epoch   0 Batch   20/538 - Train Accuracy: 0.4420, Validation Accuracy: 0.4695, Loss: 2.7342
# Epoch   0 Batch   30/538 - Train Accuracy: 0.4164, Validation Accuracy: 0.4897, Loss: 2.6188
# Epoch   0 Batch   40/538 - Train Accuracy: 0.4902, Validation Accuracy: 0.4959, Loss: 2.1538
# Epoch   0 Batch   50/538 - Train Accuracy: 0.4523, Validation Accuracy: 0.5023, Loss: 2.0891
# Epoch   0 Batch   60/538 - Train Accuracy: 0.4488, Validation Accuracy: 0.4993, Loss: 1.9369
# Epoch   0 Batch   70/538 - Train Accuracy: 0.4849, Validation Accuracy: 0.5169, Loss: 1.7591
# Epoch   0 Batch   80/538 - Train Accuracy: 0.4551, Validation Accuracy: 0.5085, Loss: 1.7564
# Epoch   0 Batch   90/538 - Train Accuracy: 0.4643, Validation Accuracy: 0.4879, Loss: 1.5551
# Epoch   0 Batch  100/538 - Train Accuracy: 0.5076, Validation Accuracy: 0.5341, Loss: 1.4773
# Epoch   0 Batch  110/538 - Train Accuracy: 0.4943, Validation Accuracy: 0.5357, Loss: 1.4692
# Epoch   0 Batch  120/538 - Train Accuracy: 0.4939, Validation Accuracy: 0.5376, Loss: 1.3438
# Epoch   0 Batch  130/538 - Train Accuracy: 0.5314, Validation Accuracy: 0.5515, Loss: 1.2619
# Epoch   0 Batch  140/538 - Train Accuracy: 0.4602, Validation Accuracy: 0.5312, Loss: 1.2947
# Epoch   0 Batch  150/538 - Train Accuracy: 0.5326, Validation Accuracy: 0.5600, Loss: 1.1476
# Epoch   0 Batch  160/538 - Train Accuracy: 0.5277, Validation Accuracy: 0.5547, Loss: 1.0512
# Epoch   0 Batch  170/538 - Train Accuracy: 0.5878, Validation Accuracy: 0.5744, Loss: 1.0030
# Epoch   0 Batch  180/538 - Train Accuracy: 0.5727, Validation Accuracy: 0.5751, Loss: 0.9741
# Epoch   0 Batch  190/538 - Train Accuracy: 0.5709, Validation Accuracy: 0.5826, Loss: 0.9825
# Epoch   0 Batch  200/538 - Train Accuracy: 0.5787, Validation Accuracy: 0.5852, Loss: 0.9227
# Epoch   0 Batch  210/538 - Train Accuracy: 0.5666, Validation Accuracy: 0.5932, Loss: 0.8768
# Epoch   0 Batch  220/538 - Train Accuracy: 0.5580, Validation Accuracy: 0.5913, Loss: 0.8584
# Epoch   0 Batch  230/538 - Train Accuracy: 0.5781, Validation Accuracy: 0.6025, Loss: 0.8350
# Epoch   0 Batch  240/538 - Train Accuracy: 0.5758, Validation Accuracy: 0.6040, Loss: 0.8572
# Epoch   0 Batch  250/538 - Train Accuracy: 0.5869, Validation Accuracy: 0.6062, Loss: 0.7789
# Epoch   0 Batch  260/538 - Train Accuracy: 0.6107, Validation Accuracy: 0.6220, Loss: 0.7608
# Epoch   0 Batch  270/538 - Train Accuracy: 0.6029, Validation Accuracy: 0.6321, Loss: 0.7322
# Epoch   0 Batch  280/538 - Train Accuracy: 0.6429, Validation Accuracy: 0.6280, Loss: 0.6973
# Epoch   0 Batch  290/538 - Train Accuracy: 0.6105, Validation Accuracy: 0.6365, Loss: 0.6931
# Epoch   0 Batch  300/538 - Train Accuracy: 0.6323, Validation Accuracy: 0.6380, Loss: 0.6796
# Epoch   0 Batch  310/538 - Train Accuracy: 0.6264, Validation Accuracy: 0.6376, Loss: 0.6566
# Epoch   0 Batch  320/538 - Train Accuracy: 0.6339, Validation Accuracy: 0.6337, Loss: 0.6339
# Epoch   0 Batch  330/538 - Train Accuracy: 0.6406, Validation Accuracy: 0.6380, Loss: 0.6062
# Epoch   0 Batch  340/538 - Train Accuracy: 0.6326, Validation Accuracy: 0.6481, Loss: 0.6198
# Epoch   0 Batch  350/538 - Train Accuracy: 0.6230, Validation Accuracy: 0.6394, Loss: 0.6123
# Epoch   0 Batch  360/538 - Train Accuracy: 0.6189, Validation Accuracy: 0.6488, Loss: 0.5896
# Epoch   0 Batch  370/538 - Train Accuracy: 0.6336, Validation Accuracy: 0.6621, Loss: 0.5889
# Epoch   0 Batch  380/538 - Train Accuracy: 0.6541, Validation Accuracy: 0.6816, Loss: 0.5495
# Epoch   0 Batch  390/538 - Train Accuracy: 0.7039, Validation Accuracy: 0.6706, Loss: 0.5093
# Epoch   0 Batch  400/538 - Train Accuracy: 0.6793, Validation Accuracy: 0.6898, Loss: 0.5177
# Epoch   0 Batch  410/538 - Train Accuracy: 0.6916, Validation Accuracy: 0.6983, Loss: 0.5087
# Epoch   0 Batch  420/538 - Train Accuracy: 0.7195, Validation Accuracy: 0.7118, Loss: 0.4888
# Epoch   0 Batch  430/538 - Train Accuracy: 0.7188, Validation Accuracy: 0.7013, Loss: 0.4793
# Epoch   0 Batch  440/538 - Train Accuracy: 0.7273, Validation Accuracy: 0.7205, Loss: 0.4980
# Epoch   0 Batch  450/538 - Train Accuracy: 0.7323, Validation Accuracy: 0.7349, Loss: 0.4539
# Epoch   0 Batch  460/538 - Train Accuracy: 0.7024, Validation Accuracy: 0.7376, Loss: 0.4226
# Epoch   0 Batch  470/538 - Train Accuracy: 0.7394, Validation Accuracy: 0.7498, Loss: 0.3972
# Epoch   0 Batch  480/538 - Train Accuracy: 0.7638, Validation Accuracy: 0.7626, Loss: 0.3816
# Epoch   0 Batch  490/538 - Train Accuracy: 0.7667, Validation Accuracy: 0.7463, Loss: 0.3694
# Epoch   0 Batch  500/538 - Train Accuracy: 0.8072, Validation Accuracy: 0.7889, Loss: 0.3256
# Epoch   0 Batch  510/538 - Train Accuracy: 0.8077, Validation Accuracy: 0.7903, Loss: 0.3300
# Epoch   0 Batch  520/538 - Train Accuracy: 0.7846, Validation Accuracy: 0.8134, Loss: 0.3564
# Epoch   0 Batch  530/538 - Train Accuracy: 0.7846, Validation Accuracy: 0.7997, Loss: 0.3437
# Epoch   1 Batch   10/538 - Train Accuracy: 0.8184, Validation Accuracy: 0.7967, Loss: 0.3005
# Epoch   1 Batch   20/538 - Train Accuracy: 0.8183, Validation Accuracy: 0.8093, Loss: 0.2843
# Epoch   1 Batch   30/538 - Train Accuracy: 0.8373, Validation Accuracy: 0.8333, Loss: 0.2779
# Epoch   1 Batch   40/538 - Train Accuracy: 0.8390, Validation Accuracy: 0.8413, Loss: 0.2322
# Epoch   1 Batch   50/538 - Train Accuracy: 0.8311, Validation Accuracy: 0.8319, Loss: 0.2409
# Epoch   1 Batch   60/538 - Train Accuracy: 0.8643, Validation Accuracy: 0.8350, Loss: 0.2217
# Epoch   1 Batch   70/538 - Train Accuracy: 0.8534, Validation Accuracy: 0.8436, Loss: 0.2157
# Epoch   1 Batch   80/538 - Train Accuracy: 0.8484, Validation Accuracy: 0.8281, Loss: 0.2144
# Epoch   1 Batch   90/538 - Train Accuracy: 0.8516, Validation Accuracy: 0.8404, Loss: 0.2198
# Epoch   1 Batch  100/538 - Train Accuracy: 0.8910, Validation Accuracy: 0.8562, Loss: 0.1867
# Epoch   1 Batch  110/538 - Train Accuracy: 0.8539, Validation Accuracy: 0.8587, Loss: 0.1958
# Epoch   1 Batch  120/538 - Train Accuracy: 0.8971, Validation Accuracy: 0.8686, Loss: 0.1665
# Epoch   1 Batch  130/538 - Train Accuracy: 0.8823, Validation Accuracy: 0.8601, Loss: 0.1544
# Epoch   1 Batch  140/538 - Train Accuracy: 0.8604, Validation Accuracy: 0.8713, Loss: 0.1860
# Epoch   1 Batch  150/538 - Train Accuracy: 0.8850, Validation Accuracy: 0.8801, Loss: 0.1491
# Epoch   1 Batch  160/538 - Train Accuracy: 0.8557, Validation Accuracy: 0.8878, Loss: 0.1382
# Epoch   1 Batch  170/538 - Train Accuracy: 0.8821, Validation Accuracy: 0.8809, Loss: 0.1590
# Epoch   1 Batch  180/538 - Train Accuracy: 0.9074, Validation Accuracy: 0.8700, Loss: 0.1649
# Epoch   1 Batch  190/538 - Train Accuracy: 0.8832, Validation Accuracy: 0.8901, Loss: 0.1717
# Epoch   1 Batch  200/538 - Train Accuracy: 0.8754, Validation Accuracy: 0.8883, Loss: 0.1317
# Epoch   1 Batch  210/538 - Train Accuracy: 0.8689, Validation Accuracy: 0.8896, Loss: 0.1381
# Epoch   1 Batch  220/538 - Train Accuracy: 0.8849, Validation Accuracy: 0.8956, Loss: 0.1319
# Epoch   1 Batch  230/538 - Train Accuracy: 0.8893, Validation Accuracy: 0.8727, Loss: 0.1235
# Epoch   1 Batch  240/538 - Train Accuracy: 0.8969, Validation Accuracy: 0.8901, Loss: 0.1358
# Epoch   1 Batch  250/538 - Train Accuracy: 0.9324, Validation Accuracy: 0.9032, Loss: 0.1123
# Epoch   1 Batch  260/538 - Train Accuracy: 0.8711, Validation Accuracy: 0.8988, Loss: 0.1251
# Epoch   1 Batch  270/538 - Train Accuracy: 0.8994, Validation Accuracy: 0.9032, Loss: 0.1073
# Epoch   1 Batch  280/538 - Train Accuracy: 0.9053, Validation Accuracy: 0.8908, Loss: 0.0987
# Epoch   1 Batch  290/538 - Train Accuracy: 0.9107, Validation Accuracy: 0.8883, Loss: 0.0990
# Epoch   1 Batch  300/538 - Train Accuracy: 0.9074, Validation Accuracy: 0.9091, Loss: 0.1054
# Epoch   1 Batch  310/538 - Train Accuracy: 0.9213, Validation Accuracy: 0.9197, Loss: 0.1055
# Epoch   1 Batch  320/538 - Train Accuracy: 0.9221, Validation Accuracy: 0.9139, Loss: 0.0941
# Epoch   1 Batch  330/538 - Train Accuracy: 0.9122, Validation Accuracy: 0.8954, Loss: 0.0936
# Epoch   1 Batch  340/538 - Train Accuracy: 0.9000, Validation Accuracy: 0.9100, Loss: 0.1052
# Epoch   1 Batch  350/538 - Train Accuracy: 0.9129, Validation Accuracy: 0.9022, Loss: 0.1015
# Epoch   1 Batch  360/538 - Train Accuracy: 0.9145, Validation Accuracy: 0.9162, Loss: 0.1019
# Epoch   1 Batch  370/538 - Train Accuracy: 0.9256, Validation Accuracy: 0.9078, Loss: 0.0910
# Epoch   1 Batch  380/538 - Train Accuracy: 0.9018, Validation Accuracy: 0.8963, Loss: 0.0852
# Epoch   1 Batch  390/538 - Train Accuracy: 0.9237, Validation Accuracy: 0.9082, Loss: 0.0741
# Epoch   1 Batch  400/538 - Train Accuracy: 0.9371, Validation Accuracy: 0.8961, Loss: 0.0897
# Epoch   1 Batch  410/538 - Train Accuracy: 0.9064, Validation Accuracy: 0.9224, Loss: 0.0905
# Epoch   1 Batch  420/538 - Train Accuracy: 0.9285, Validation Accuracy: 0.9194, Loss: 0.0735
# Epoch   1 Batch  430/538 - Train Accuracy: 0.9178, Validation Accuracy: 0.9242, Loss: 0.0784
# Epoch   1 Batch  440/538 - Train Accuracy: 0.9154, Validation Accuracy: 0.9125, Loss: 0.0960
# Epoch   1 Batch  450/538 - Train Accuracy: 0.9096, Validation Accuracy: 0.9082, Loss: 0.0987
# Epoch   1 Batch  460/538 - Train Accuracy: 0.9089, Validation Accuracy: 0.9093, Loss: 0.0937
# Epoch   1 Batch  470/538 - Train Accuracy: 0.9241, Validation Accuracy: 0.9118, Loss: 0.0822
# Epoch   1 Batch  480/538 - Train Accuracy: 0.9330, Validation Accuracy: 0.9270, Loss: 0.0705
# Epoch   1 Batch  490/538 - Train Accuracy: 0.9343, Validation Accuracy: 0.9128, Loss: 0.0731
# Epoch   1 Batch  500/538 - Train Accuracy: 0.9350, Validation Accuracy: 0.9213, Loss: 0.0608
# Epoch   1 Batch  510/538 - Train Accuracy: 0.9386, Validation Accuracy: 0.9277, Loss: 0.0706
# Epoch   1 Batch  520/538 - Train Accuracy: 0.9330, Validation Accuracy: 0.9249, Loss: 0.0659
# Epoch   1 Batch  530/538 - Train Accuracy: 0.9102, Validation Accuracy: 0.9201, Loss: 0.0789
# Epoch   2 Batch   10/538 - Train Accuracy: 0.9254, Validation Accuracy: 0.9084, Loss: 0.0794
# Epoch   2 Batch   20/538 - Train Accuracy: 0.9250, Validation Accuracy: 0.9228, Loss: 0.0761
# Epoch   2 Batch   30/538 - Train Accuracy: 0.9178, Validation Accuracy: 0.9126, Loss: 0.0757
# Epoch   2 Batch   40/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9137, Loss: 0.0528
# Epoch   2 Batch   50/538 - Train Accuracy: 0.9187, Validation Accuracy: 0.9336, Loss: 0.0649
# Epoch   2 Batch   60/538 - Train Accuracy: 0.9371, Validation Accuracy: 0.9292, Loss: 0.0641
# Epoch   2 Batch   70/538 - Train Accuracy: 0.9202, Validation Accuracy: 0.9173, Loss: 0.0649
# Epoch   2 Batch   80/538 - Train Accuracy: 0.9322, Validation Accuracy: 0.9251, Loss: 0.0701
# Epoch   2 Batch   90/538 - Train Accuracy: 0.9358, Validation Accuracy: 0.9215, Loss: 0.0678
# Epoch   2 Batch  100/538 - Train Accuracy: 0.9283, Validation Accuracy: 0.9217, Loss: 0.0659
# Epoch   2 Batch  110/538 - Train Accuracy: 0.9330, Validation Accuracy: 0.9228, Loss: 0.0626
# Epoch   2 Batch  120/538 - Train Accuracy: 0.9459, Validation Accuracy: 0.9380, Loss: 0.0535
# Epoch   2 Batch  130/538 - Train Accuracy: 0.9386, Validation Accuracy: 0.9395, Loss: 0.0547
# Epoch   2 Batch  140/538 - Train Accuracy: 0.9100, Validation Accuracy: 0.9293, Loss: 0.0885
# Epoch   2 Batch  150/538 - Train Accuracy: 0.9367, Validation Accuracy: 0.9389, Loss: 0.0578
# Epoch   2 Batch  160/538 - Train Accuracy: 0.9291, Validation Accuracy: 0.9224, Loss: 0.0540
# Epoch   2 Batch  170/538 - Train Accuracy: 0.9347, Validation Accuracy: 0.9185, Loss: 0.0570
# Epoch   2 Batch  180/538 - Train Accuracy: 0.9355, Validation Accuracy: 0.9157, Loss: 0.0617
# Epoch   2 Batch  190/538 - Train Accuracy: 0.9295, Validation Accuracy: 0.9355, Loss: 0.0790
# Epoch   2 Batch  200/538 - Train Accuracy: 0.9430, Validation Accuracy: 0.9276, Loss: 0.0477
# Epoch   2 Batch  210/538 - Train Accuracy: 0.9343, Validation Accuracy: 0.9398, Loss: 0.0597
# Epoch   2 Batch  220/538 - Train Accuracy: 0.9297, Validation Accuracy: 0.9411, Loss: 0.0575
# Epoch   2 Batch  230/538 - Train Accuracy: 0.9285, Validation Accuracy: 0.9386, Loss: 0.0583
# Epoch   2 Batch  240/538 - Train Accuracy: 0.9363, Validation Accuracy: 0.9409, Loss: 0.0575
# Epoch   2 Batch  250/538 - Train Accuracy: 0.9447, Validation Accuracy: 0.9293, Loss: 0.0549
# Epoch   2 Batch  260/538 - Train Accuracy: 0.9109, Validation Accuracy: 0.9284, Loss: 0.0646
# Epoch   2 Batch  270/538 - Train Accuracy: 0.9283, Validation Accuracy: 0.9416, Loss: 0.0508
# Epoch   2 Batch  280/538 - Train Accuracy: 0.9446, Validation Accuracy: 0.9190, Loss: 0.0471
# Epoch   2 Batch  290/538 - Train Accuracy: 0.9592, Validation Accuracy: 0.9221, Loss: 0.0496
# Epoch   2 Batch  300/538 - Train Accuracy: 0.9414, Validation Accuracy: 0.9450, Loss: 0.0538
# Epoch   2 Batch  310/538 - Train Accuracy: 0.9607, Validation Accuracy: 0.9382, Loss: 0.0572
# Epoch   2 Batch  320/538 - Train Accuracy: 0.9516, Validation Accuracy: 0.9414, Loss: 0.0500
# Epoch   2 Batch  330/538 - Train Accuracy: 0.9632, Validation Accuracy: 0.9409, Loss: 0.0524
# Epoch   2 Batch  340/538 - Train Accuracy: 0.9428, Validation Accuracy: 0.9576, Loss: 0.0548
# Epoch   2 Batch  350/538 - Train Accuracy: 0.9366, Validation Accuracy: 0.9423, Loss: 0.0548
# Epoch   2 Batch  360/538 - Train Accuracy: 0.9492, Validation Accuracy: 0.9403, Loss: 0.0442
# Epoch   2 Batch  370/538 - Train Accuracy: 0.9570, Validation Accuracy: 0.9496, Loss: 0.0502
# Epoch   2 Batch  380/538 - Train Accuracy: 0.9447, Validation Accuracy: 0.9448, Loss: 0.0490
# Epoch   2 Batch  390/538 - Train Accuracy: 0.9481, Validation Accuracy: 0.9473, Loss: 0.0425
# Epoch   2 Batch  400/538 - Train Accuracy: 0.9609, Validation Accuracy: 0.9407, Loss: 0.0465
# Epoch   2 Batch  410/538 - Train Accuracy: 0.9477, Validation Accuracy: 0.9425, Loss: 0.0543
# Epoch   2 Batch  420/538 - Train Accuracy: 0.9416, Validation Accuracy: 0.9467, Loss: 0.0510
# Epoch   2 Batch  430/538 - Train Accuracy: 0.9451, Validation Accuracy: 0.9487, Loss: 0.0549
# Epoch   2 Batch  440/538 - Train Accuracy: 0.9514, Validation Accuracy: 0.9366, Loss: 0.0539
# Epoch   2 Batch  450/538 - Train Accuracy: 0.9347, Validation Accuracy: 0.9490, Loss: 0.0575
# Epoch   2 Batch  460/538 - Train Accuracy: 0.9297, Validation Accuracy: 0.9389, Loss: 0.0544
# Epoch   2 Batch  470/538 - Train Accuracy: 0.9531, Validation Accuracy: 0.9522, Loss: 0.0464
# Epoch   2 Batch  480/538 - Train Accuracy: 0.9565, Validation Accuracy: 0.9386, Loss: 0.0437
# Epoch   2 Batch  490/538 - Train Accuracy: 0.9475, Validation Accuracy: 0.9371, Loss: 0.0472
# Epoch   2 Batch  500/538 - Train Accuracy: 0.9650, Validation Accuracy: 0.9425, Loss: 0.0335
# Epoch   2 Batch  510/538 - Train Accuracy: 0.9613, Validation Accuracy: 0.9428, Loss: 0.0431
# Epoch   2 Batch  520/538 - Train Accuracy: 0.9467, Validation Accuracy: 0.9414, Loss: 0.0460
# Epoch   2 Batch  530/538 - Train Accuracy: 0.9254, Validation Accuracy: 0.9442, Loss: 0.0538
# Epoch   3 Batch   10/538 - Train Accuracy: 0.9426, Validation Accuracy: 0.9579, Loss: 0.0488
# Epoch   3 Batch   20/538 - Train Accuracy: 0.9457, Validation Accuracy: 0.9471, Loss: 0.0452
# Epoch   3 Batch   30/538 - Train Accuracy: 0.9385, Validation Accuracy: 0.9540, Loss: 0.0504
# Epoch   3 Batch   40/538 - Train Accuracy: 0.9622, Validation Accuracy: 0.9540, Loss: 0.0371
# Epoch   3 Batch   50/538 - Train Accuracy: 0.9443, Validation Accuracy: 0.9435, Loss: 0.0392
# Epoch   3 Batch   60/538 - Train Accuracy: 0.9525, Validation Accuracy: 0.9418, Loss: 0.0395
# Epoch   3 Batch   70/538 - Train Accuracy: 0.9501, Validation Accuracy: 0.9348, Loss: 0.0379
# Epoch   3 Batch   80/538 - Train Accuracy: 0.9533, Validation Accuracy: 0.9444, Loss: 0.0411
# Epoch   3 Batch   90/538 - Train Accuracy: 0.9563, Validation Accuracy: 0.9489, Loss: 0.0406
# Epoch   3 Batch  100/538 - Train Accuracy: 0.9635, Validation Accuracy: 0.9556, Loss: 0.0347
# Epoch   3 Batch  110/538 - Train Accuracy: 0.9572, Validation Accuracy: 0.9462, Loss: 0.0383
# Epoch   3 Batch  120/538 - Train Accuracy: 0.9711, Validation Accuracy: 0.9570, Loss: 0.0315
# Epoch   3 Batch  130/538 - Train Accuracy: 0.9529, Validation Accuracy: 0.9487, Loss: 0.0389
# Epoch   3 Batch  140/538 - Train Accuracy: 0.9576, Validation Accuracy: 0.9419, Loss: 0.0547
# Epoch   3 Batch  150/538 - Train Accuracy: 0.9563, Validation Accuracy: 0.9483, Loss: 0.0351
# Epoch   3 Batch  160/538 - Train Accuracy: 0.9490, Validation Accuracy: 0.9425, Loss: 0.0410
# Epoch   3 Batch  170/538 - Train Accuracy: 0.9606, Validation Accuracy: 0.9375, Loss: 0.0391
# Epoch   3 Batch  180/538 - Train Accuracy: 0.9587, Validation Accuracy: 0.9519, Loss: 0.0403
# Epoch   3 Batch  190/538 - Train Accuracy: 0.9408, Validation Accuracy: 0.9510, Loss: 0.0508
# Epoch   3 Batch  200/538 - Train Accuracy: 0.9643, Validation Accuracy: 0.9487, Loss: 0.0283
# Epoch   3 Batch  210/538 - Train Accuracy: 0.9600, Validation Accuracy: 0.9439, Loss: 0.0406
# Epoch   3 Batch  220/538 - Train Accuracy: 0.9522, Validation Accuracy: 0.9423, Loss: 0.0385
# Epoch   3 Batch  230/538 - Train Accuracy: 0.9469, Validation Accuracy: 0.9423, Loss: 0.0366
# Epoch   3 Batch  240/538 - Train Accuracy: 0.9570, Validation Accuracy: 0.9474, Loss: 0.0447
# Epoch   3 Batch  250/538 - Train Accuracy: 0.9396, Validation Accuracy: 0.9371, Loss: 0.0392
# Epoch   3 Batch  260/538 - Train Accuracy: 0.9435, Validation Accuracy: 0.9320, Loss: 0.0441
# Epoch   3 Batch  270/538 - Train Accuracy: 0.9592, Validation Accuracy: 0.9412, Loss: 0.0326
# Epoch   3 Batch  280/538 - Train Accuracy: 0.9561, Validation Accuracy: 0.9428, Loss: 0.0327
# Epoch   3 Batch  290/538 - Train Accuracy: 0.9596, Validation Accuracy: 0.9371, Loss: 0.0345
# Epoch   3 Batch  300/538 - Train Accuracy: 0.9542, Validation Accuracy: 0.9517, Loss: 0.0406
# Epoch   3 Batch  310/538 - Train Accuracy: 0.9781, Validation Accuracy: 0.9590, Loss: 0.0353
# Epoch   3 Batch  320/538 - Train Accuracy: 0.9630, Validation Accuracy: 0.9455, Loss: 0.0277
# Epoch   3 Batch  330/538 - Train Accuracy: 0.9762, Validation Accuracy: 0.9703, Loss: 0.0357
# Epoch   3 Batch  340/538 - Train Accuracy: 0.9531, Validation Accuracy: 0.9553, Loss: 0.0384
# Epoch   3 Batch  350/538 - Train Accuracy: 0.9647, Validation Accuracy: 0.9618, Loss: 0.0341
# Epoch   3 Batch  360/538 - Train Accuracy: 0.9664, Validation Accuracy: 0.9631, Loss: 0.0285
# Epoch   3 Batch  370/538 - Train Accuracy: 0.9639, Validation Accuracy: 0.9487, Loss: 0.0425
# Epoch   3 Batch  380/538 - Train Accuracy: 0.9572, Validation Accuracy: 0.9421, Loss: 0.0338
# Epoch   3 Batch  390/538 - Train Accuracy: 0.9576, Validation Accuracy: 0.9513, Loss: 0.0312
# Epoch   3 Batch  400/538 - Train Accuracy: 0.9611, Validation Accuracy: 0.9400, Loss: 0.0393
# Epoch   3 Batch  410/538 - Train Accuracy: 0.9697, Validation Accuracy: 0.9480, Loss: 0.0352
# Epoch   3 Batch  420/538 - Train Accuracy: 0.9592, Validation Accuracy: 0.9554, Loss: 0.0352
# Epoch   3 Batch  430/538 - Train Accuracy: 0.9457, Validation Accuracy: 0.9569, Loss: 0.0342
# Epoch   3 Batch  440/538 - Train Accuracy: 0.9699, Validation Accuracy: 0.9522, Loss: 0.0360
# Epoch   3 Batch  450/538 - Train Accuracy: 0.9461, Validation Accuracy: 0.9565, Loss: 0.0466
# Epoch   3 Batch  460/538 - Train Accuracy: 0.9362, Validation Accuracy: 0.9540, Loss: 0.0381
# Epoch   3 Batch  470/538 - Train Accuracy: 0.9513, Validation Accuracy: 0.9602, Loss: 0.0338
# Epoch   3 Batch  480/538 - Train Accuracy: 0.9684, Validation Accuracy: 0.9616, Loss: 0.0304
# Epoch   3 Batch  490/538 - Train Accuracy: 0.9587, Validation Accuracy: 0.9476, Loss: 0.0345
# Epoch   3 Batch  500/538 - Train Accuracy: 0.9707, Validation Accuracy: 0.9547, Loss: 0.0251
# Epoch   3 Batch  510/538 - Train Accuracy: 0.9650, Validation Accuracy: 0.9512, Loss: 0.0324
# Epoch   3 Batch  520/538 - Train Accuracy: 0.9629, Validation Accuracy: 0.9455, Loss: 0.0321
# Epoch   3 Batch  530/538 - Train Accuracy: 0.9490, Validation Accuracy: 0.9545, Loss: 0.0351
# Epoch   4 Batch   10/538 - Train Accuracy: 0.9584, Validation Accuracy: 0.9627, Loss: 0.0374
# Epoch   4 Batch   20/538 - Train Accuracy: 0.9658, Validation Accuracy: 0.9618, Loss: 0.0434
# Epoch   4 Batch   30/538 - Train Accuracy: 0.9473, Validation Accuracy: 0.9579, Loss: 0.0409
# Epoch   4 Batch   40/538 - Train Accuracy: 0.9647, Validation Accuracy: 0.9542, Loss: 0.0284
# Epoch   4 Batch   50/538 - Train Accuracy: 0.9521, Validation Accuracy: 0.9496, Loss: 0.0459
# Epoch   4 Batch   60/538 - Train Accuracy: 0.9678, Validation Accuracy: 0.9405, Loss: 0.0391
# Epoch   4 Batch   70/538 - Train Accuracy: 0.9572, Validation Accuracy: 0.9579, Loss: 0.0315
# Epoch   4 Batch   80/538 - Train Accuracy: 0.9607, Validation Accuracy: 0.9547, Loss: 0.0342
# Epoch   4 Batch   90/538 - Train Accuracy: 0.9667, Validation Accuracy: 0.9673, Loss: 0.0407
# Epoch   4 Batch  100/538 - Train Accuracy: 0.9658, Validation Accuracy: 0.9682, Loss: 0.0300
# Epoch   4 Batch  110/538 - Train Accuracy: 0.9736, Validation Accuracy: 0.9567, Loss: 0.0318
# Epoch   4 Batch  120/538 - Train Accuracy: 0.9729, Validation Accuracy: 0.9595, Loss: 0.0213
# Epoch   4 Batch  130/538 - Train Accuracy: 0.9626, Validation Accuracy: 0.9705, Loss: 0.0290
# Epoch   4 Batch  140/538 - Train Accuracy: 0.9488, Validation Accuracy: 0.9487, Loss: 0.0420
# Epoch   4 Batch  150/538 - Train Accuracy: 0.9658, Validation Accuracy: 0.9492, Loss: 0.0305
# Epoch   4 Batch  160/538 - Train Accuracy: 0.9574, Validation Accuracy: 0.9600, Loss: 0.0320
# Epoch   4 Batch  170/538 - Train Accuracy: 0.9511, Validation Accuracy: 0.9551, Loss: 0.0295
# Epoch   4 Batch  180/538 - Train Accuracy: 0.9680, Validation Accuracy: 0.9654, Loss: 0.0319
# Epoch   4 Batch  190/538 - Train Accuracy: 0.9583, Validation Accuracy: 0.9490, Loss: 0.0350
# Epoch   4 Batch  200/538 - Train Accuracy: 0.9705, Validation Accuracy: 0.9624, Loss: 0.0235
# Epoch   4 Batch  210/538 - Train Accuracy: 0.9676, Validation Accuracy: 0.9579, Loss: 0.0337
# Epoch   4 Batch  220/538 - Train Accuracy: 0.9606, Validation Accuracy: 0.9592, Loss: 0.0298
# Epoch   4 Batch  230/538 - Train Accuracy: 0.9514, Validation Accuracy: 0.9553, Loss: 0.0298
# Epoch   4 Batch  240/538 - Train Accuracy: 0.9635, Validation Accuracy: 0.9625, Loss: 0.0318
# Epoch   4 Batch  250/538 - Train Accuracy: 0.9621, Validation Accuracy: 0.9485, Loss: 0.0333
# Epoch   4 Batch  260/538 - Train Accuracy: 0.9423, Validation Accuracy: 0.9462, Loss: 0.0397
# Epoch   4 Batch  270/538 - Train Accuracy: 0.9777, Validation Accuracy: 0.9586, Loss: 0.0260
# Epoch   4 Batch  280/538 - Train Accuracy: 0.9717, Validation Accuracy: 0.9513, Loss: 0.0247
# Epoch   4 Batch  290/538 - Train Accuracy: 0.9762, Validation Accuracy: 0.9567, Loss: 0.0261
# Epoch   4 Batch  300/538 - Train Accuracy: 0.9632, Validation Accuracy: 0.9600, Loss: 0.0281
# Epoch   4 Batch  310/538 - Train Accuracy: 0.9703, Validation Accuracy: 0.9711, Loss: 0.0347
# Epoch   4 Batch  320/538 - Train Accuracy: 0.9641, Validation Accuracy: 0.9700, Loss: 0.0278
# Epoch   4 Batch  330/538 - Train Accuracy: 0.9786, Validation Accuracy: 0.9604, Loss: 0.0238
# Epoch   4 Batch  340/538 - Train Accuracy: 0.9725, Validation Accuracy: 0.9595, Loss: 0.0225
# Epoch   4 Batch  350/538 - Train Accuracy: 0.9699, Validation Accuracy: 0.9627, Loss: 0.0352
# Epoch   4 Batch  360/538 - Train Accuracy: 0.9691, Validation Accuracy: 0.9698, Loss: 0.0245
# Epoch   4 Batch  370/538 - Train Accuracy: 0.9777, Validation Accuracy: 0.9666, Loss: 0.0272
# Epoch   4 Batch  380/538 - Train Accuracy: 0.9662, Validation Accuracy: 0.9615, Loss: 0.0255
# Epoch   4 Batch  390/538 - Train Accuracy: 0.9630, Validation Accuracy: 0.9618, Loss: 0.0200
# Epoch   4 Batch  400/538 - Train Accuracy: 0.9779, Validation Accuracy: 0.9579, Loss: 0.0293
# Epoch   4 Batch  410/538 - Train Accuracy: 0.9828, Validation Accuracy: 0.9599, Loss: 0.0249
# Epoch   4 Batch  420/538 - Train Accuracy: 0.9719, Validation Accuracy: 0.9661, Loss: 0.0256
# Epoch   4 Batch  430/538 - Train Accuracy: 0.9607, Validation Accuracy: 0.9664, Loss: 0.0261
# Epoch   4 Batch  440/538 - Train Accuracy: 0.9824, Validation Accuracy: 0.9732, Loss: 0.0264
# Epoch   4 Batch  450/538 - Train Accuracy: 0.9606, Validation Accuracy: 0.9659, Loss: 0.0340
# Epoch   4 Batch  460/538 - Train Accuracy: 0.9544, Validation Accuracy: 0.9599, Loss: 0.0302
# Epoch   4 Batch  470/538 - Train Accuracy: 0.9688, Validation Accuracy: 0.9650, Loss: 0.0274
# Epoch   4 Batch  480/538 - Train Accuracy: 0.9749, Validation Accuracy: 0.9645, Loss: 0.0241
# Epoch   4 Batch  490/538 - Train Accuracy: 0.9632, Validation Accuracy: 0.9703, Loss: 0.0253
# Epoch   4 Batch  500/538 - Train Accuracy: 0.9838, Validation Accuracy: 0.9577, Loss: 0.0168
# Epoch   4 Batch  510/538 - Train Accuracy: 0.9712, Validation Accuracy: 0.9588, Loss: 0.0234
# Epoch   4 Batch  520/538 - Train Accuracy: 0.9654, Validation Accuracy: 0.9540, Loss: 0.0283
# Epoch   4 Batch  530/538 - Train Accuracy: 0.9609, Validation Accuracy: 0.9679, Loss: 0.0261
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # DONE: Implement Function
    sentence = sentence.lower()
    return [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in sentence.split()]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
def translate(translate_sentence, batch_size=256):
    """
    DON'T MODIFY ANYTHING IN THIS CELL
    """
    translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

    loaded_graph = tf.Graph()
    with tf.Session(graph=loaded_graph) as sess:
        # Load saved model
        loader = tf.train.import_meta_graph(load_path + '.meta')
        loader.restore(sess, load_path)

        input_data = loaded_graph.get_tensor_by_name('input:0')
        logits = loaded_graph.get_tensor_by_name('predictions:0')
        target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
        source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
        keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

        translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                             target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                             source_sequence_length: [len(translate_sentence)]*batch_size,
                                             keep_prob: 1.0})[0]

    print('Input')
    print('  Word Ids:      {}'.format([i for i in translate_sentence]))
    print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

    print('\nPrediction')
    print('  Word Ids:      {}'.format([i for i in translate_logits]))
    print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
    
    print("\n\n")

translate('he saw a old yellow truck .')
translate('my favorite animal is a dog .')
translate('sometimes , dog dislike fruit .')
translate('paris is freezing .')
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [18, 169, 124, 102, 121, 139, 200]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [308, 132, 129, 264, 253, 348, 259, 167, 1]
#   French Words: il a vu un vieux camion jaune . <EOS>
#
#
#
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [52, 74, 204, 93, 124, 211, 200]
#   English Words: ['my', 'favorite', 'animal', 'is', 'a', 'dog', '.']
#
# Prediction
#   Word Ids:      [271, 350, 281, 306, 24, 287, 167, 1]
#   French Words: mon animal préféré est le chien . <EOS>
#
#
#
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [197, 173, 211, 223, 101, 200]
#   English Words: ['sometimes', ',', 'dog', 'dislike', 'fruit', '.']
#
# Prediction
#   Word Ids:      [271, 213, 281, 306, 127, 80, 158, 328, 161, 281, 306, 167]
#   French Words: mon fruit préféré est la banane , mais notre préféré est .
#
#
#
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [25, 93, 4, 200]
#   English Words: ['paris', 'is', 'freezing', '.']
#
# Prediction
#   Word Ids:      [24, 233, 306, 152, 194, 158, 328, 308]
#   French Words: le gel est l' automne , mais il

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
